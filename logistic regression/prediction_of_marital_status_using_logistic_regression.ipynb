# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib  inline

# %%
df= pd.read_csv('marital status.csv')
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     NaN
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df.isnull().sum()
# Out:
# age       0
# status    1
# dtype: int64

# %%
handle = df['status'].median()
handle
# Out:
# 0.0

# %%
df.status= df.status.fillna(handle)
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     0.0
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df['status'].value_counts()
# Out:
# status
# 0.0    11
# 1.0     9
# Name: count, dtype: int64

# %%
x = df[['age']]
x
# Out:
#     age
# 0    21
# 1    33
# 2    24
# 3    28
# 4    17
# 5    33
# 6    23
# 7    30
# 8    29
# 9    22
# 10   26
# 11   20
# 12   22
# 13   24
# 14   34
# 15   29
# 16   16
# 17   18
# 18   26
# 19   25

# %%
y = df[['status']]
y
# Out:
#     status
# 0      0.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      0.0
# 5      1.0
# 6      0.0
# 7      0.0
# 8      1.0
# 9      0.0
# 10     1.0
# 11     0.0
# 12     0.0
# 13     0.0
# 14     1.0
# 15     1.0
# 16     0.0
# 17     0.0
# 18     1.0
# 19     1.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()

# %%
model.fit(X_test,Y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0., 0., 1., 0.])

# %%
model.score(X_test,Y_test)
# Out:
# 1.0

# %%
model.predict_log_proba(X_test)
# Out:
# array([[-1.38131828e-01, -2.04781780e+00],
#        [-2.24690860e-03, -6.09932321e+00],
#        [-1.65281364e+00, -2.12587351e-01],
#        [-6.21382198e-02, -2.80930226e+00]])

# %%
df['predicted status'] = model.predict(df[['age']])
df
# Out:
#     age  status  predicted status
# 0    21     0.0               0.0
# 1    33     1.0               1.0
# 2    24     0.0               0.0
# 3    28     1.0               1.0
# 4    17     0.0               0.0
# 5    33     1.0               1.0
# 6    23     0.0               0.0
# 7    30     0.0               1.0
# 8    29     1.0               1.0
# 9    22     0.0               0.0
# 10   26     1.0               1.0
# 11   20     0.0               0.0
# 12   22     0.0               0.0
# 13   24     0.0               0.0
# 14   34     1.0               1.0
# 15   29     1.0               1.0
# 16   16     0.0               0.0
# 17   18     0.0               0.0
# 18   26     1.0               1.0
# 19   25     1.0               1.0

# %%
plt.plot(df['status'])
plt.plot(df[['predicted status']])
